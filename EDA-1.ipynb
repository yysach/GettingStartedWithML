# %% [markdown]
# # Univariate, Bivariate and Multivariate Analysis
#
# ### 1. Univariate data –
# This type of data consists of only one variable.The analysis of univariate data is thus the simplest form of analysis since the information deals with only one quantity that changes. It does not deal with causes or relationships and the main purpose of the analysis is to describe the data and find patterns that exist within it. The example of a univariate data can be height.
#
# ### 2. Bivariate data --
# This type of data involves two different variables. The analysis of this type of data deals with causes and relationships and the analysis is done to find out the relationship among the two variables.Example of bivariate data can be temperature and ice cream sales in summer season.
#
# ### 3. Multivariate data –
# When the data involves three or more variables, it is categorized under multivariate. Example of this type of data is suppose an advertiser wants to compare the popularity of four advertisements on a website, then their click rates could be measured for both men and women and relationships between variables can then be examined.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import load_iris #sklern also contain some famous datasets
iris=load_iris()
print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
df1=pd.DataFrame(iris.data,columns=iris.feature_names)
df2=pd.DataFrame(iris.target,columns=['target'])
df=pd.concat([df1,df2],axis=1)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.drop('target',axis='columns').plot.kde()

# %% [markdown]
# ### Univariate Analysis

# %%
df_setosa=df[df.target==0]
df_versicolor=df[df.target==1]
df_virginica=df[df.target==2]

plt.plot(df_setosa['sepal length (cm)'],np.zeros_like(df_setosa['sepal length (cm)']),'o')
plt.plot(df_versicolor['sepal length (cm)'],np.zeros_like(df_versicolor['sepal length (cm)']),'o')
plt.plot(df_virginica['sepal length (cm)'],np.zeros_like(df_virginica['sepal length (cm)']),'o')

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df,hue='target',size=10).map(plt.scatter,'petal length (cm)','sepal length (cm)').add_legend()

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data=df,hue='target',size=3)
# Out:
# /home/sachin/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
